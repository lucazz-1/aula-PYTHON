# %% [markdown]
# <a href="https://colab.research.google.com/github/lucazz-1/aula-PYTHON/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("I comprtição de programação da Start")
ApplicationError
# Out:
#   File "/tmp/ipython-input-2037881756.py", line 1
#     aula 1
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # **aula 2**

# %% [markdown]
# # **AULA 3** tabuada

# %%
def tabuada(numero);
    for contador in ranger

# %% [markdown]
# # **aula 4  imc**

# %%
peso
